# %%
#pip install pandas

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\PRASHANT\\Downloads\\sales_customer_analytics.csv")

# %%
df.head(10)# every head is used to view the first five rose along with each  and every colum in the dataset.
# Out:
#    OrderID   OrderDate  CustomerID CustomerName       City     Product  \
# 0     1001  2024-01-01         252        Pooja      Delhi      Laptop
# 1     1002  2024-01-01         293    Siddharth     Mumbai      Mobile
# 2     1003  2024-01-01         215        Megha  Hyderabad      Mobile
# 3     1004  2024-01-01         272       Ananya  Hyderabad     Monitor
# 4     1005  2024-01-02         261        Rohit    Chennai      Tablet
# 5     1006  2024-01-02         221    Siddharth       Pune      Laptop
# 6     1007  2024-01-02         283         Riya  Bangalore        Desk
# 7     1008  2024-01-03         287        Kavya      Delhi        Desk
# 8     1009  2024-01-03         275         Riya  Hyderabad    Keyboard
# 9     1010  2024-01-03         275         Isha     Mumbai  Headphones
#
#       Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10          UPI    Returned
# ...

# %%
df.tail(10) # is used to view the last 5 rows(defult) along with each and every colum in the dataset.
# Out:
#      OrderID   OrderDate  CustomerID CustomerName       City     Product  \
# 540     1541  2024-06-27         280        Sneha    Chennai        Desk
# 541     1542  2024-06-27         202        Rahul  Bangalore      Mobile
# 542     1543  2024-06-27         292        Karan     Mumbai      Tablet
# 543     1544  2024-06-28         232        Megha       Pune       Chair
# 544     1545  2024-06-28         291       Aditya    Chennai       Mouse
# 545     1546  2024-06-28         284         Neha      Delhi     Monitor
# 546     1547  2024-06-29         224        Pooja      Delhi        Desk
# 547     1548  2024-06-29         212        Megha     Mumbai        Desk
# 548     1549  2024-06-29         250       Manish    Chennai  Headphones
# 549     1550  2024-06-30         235        Megha     Mumbai     Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 540    Furniture         2      23353         0.20   Debit Card   Delivered
# ...

# %%
df.info()# info () is used to check for information of  the datset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       550 non-null    int64
#  1   OrderDate     550 non-null    object
#  2   CustomerID    550 non-null    int64
#  3   CustomerName  550 non-null    object
#  4   City          550 non-null    object
#  5   Product       550 non-null    object
#  6   Category      550 non-null    object
#  7   Quantity      550 non-null    int64
#  8   UnitPrice     550 non-null    int64
#  9   DiscountPct   458 non-null    float64
#  10  PaymentMode   550 non-null    object
#  11  OrderStatus   550 non-null    object
#  12  Rating        512 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 56.0+ KB

# %%
df.describe()# describe() returns the statistical summary for only numrical columns.
# Out:
#            OrderID  CustomerID    Quantity     UnitPrice  DiscountPct  \
# count   550.000000  550.000000  550.000000    550.000000   458.000000
# mean   1275.500000  250.258182    2.454545  33071.741818     0.099891
# std     158.915596   29.763651    1.108309  18322.527529     0.069894
# min    1001.000000  201.000000    1.000000   1007.000000     0.000000
# 25%    1138.250000  224.000000    1.000000  17455.750000     0.050000
# 50%    1275.500000  251.000000    2.000000  33185.000000     0.100000
# 75%    1412.750000  275.000000    3.000000  49023.500000     0.150000
# max    1550.000000  300.000000    4.000000  64910.000000     0.200000
#
#            Rating
# count  512.000000
# mean     3.742188
# std      1.139891
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
df.describe(include="all") #returns the statical summary for all the colums.
# Out:
#             OrderID   OrderDate  CustomerID CustomerName     City Product  \
# count    550.000000         550  550.000000          550      550     550
# unique          NaN         182         NaN           20        6       9
# top             NaN  2024-01-01         NaN        Pooja  Chennai   Chair
# freq            NaN           4         NaN           37      102      68
# mean    1275.500000         NaN  250.258182          NaN      NaN     NaN
# std      158.915596         NaN   29.763651          NaN      NaN     NaN
# min     1001.000000         NaN  201.000000          NaN      NaN     NaN
# 25%     1138.250000         NaN  224.000000          NaN      NaN     NaN
# 50%     1275.500000         NaN  251.000000          NaN      NaN     NaN
# 75%     1412.750000         NaN  275.000000          NaN      NaN     NaN
# max     1550.000000         NaN  300.000000          NaN      NaN     NaN
#
#            Category    Quantity     UnitPrice  DiscountPct PaymentMode  \
# ...

# %% [markdown]
# ## orderID:

# %%
orderId featur have a 550 values,there is no missing value
orderID feature  is  mean grater than std ,data is less variated.
orderID feature 25% is 1138 ,data lies below this value
orderID feature 50% is 1275,data lies below this value
orderId feature 75% is 1412, data lies below this value
orderId feature  1001  minimum value
orderId feature  1550  maximum  value
# Out:
#   Cell In[9], line 1
#     orderId featur have a 550 values,there is no missing value
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## orderDate:

# %%
orderDate featur have a 550 values,there is no missing value
there are 182 unique value in column
orderDate 4 number of time of value have been repeated

# %% [markdown]
# ## customerID:

# %%
customerID featur have a 550 values,there is no missing value
customerID feature  is  mean grater than std ,data is less variated.
customerID feature 25% is 224 ,data lies below this value
customerID feature 50% is 251,data lies below this value
customerID feature 75% is 275, data lies below this value
customerID 6 number of time of value have been repeated
customerID feature  201  minimum value
customerID feature  300 maximum  value

# %% [markdown]
# ## CustomerName

# %%
The CustomerName feature contains 550 values with no missing values.
There are 20 unique customer names in this column.
The most frequent customer name is Pooja, which appears 37 times.

# %% [markdown]
# ## City

# %%
The City feature contains 550 values with no missing values.
There are 6 unique cities in the dataset.
The most common city is Chennai, appearing 102 times.

# %% [markdown]
# ## Product

# %%
The Product feature contains 550 values with no missing values.
There are 9 unique products in the dataset.
The most frequently sold product is Chair, appearing 68 times.

# %% [markdown]
# ## Category

# %%
The Category feature contains 550 values with no missing values.
There are 3 unique categories in the dataset.
The most frequent category is Electronics, appearing 243 times.

# %% [markdown]
# ## Quantity

# %%
Quantity featur have a 550 values,there is no missing value
Quantityfeature  is  mean grater than std ,data is less variated.
Quantity feature 25% is 1 ,data lies below this value
Quantity feature 50% is 2,data lies below this value
Quantity feature 75% is 3, data lies below this value
Quantity feature  1  minimum value
Quantity feature  4 maximum  value

# %% [markdown]
# ## UnitPrice

# %%
UnitPrice featur have a 550 values,there is no missing value
UnitPrice feature  is  mean grater than std ,data is less variated.
UnitPrice feature 25% is 17455 ,data lies below this value
UnitPrice feature 50% is 33185,data lies below this value
UnitPrice feature 75% is 49023, data lies below this value
UnitPricefeature  1007 minimum value
UnitPrice feature  64910 maximum  value
# Out:
#   Cell In[10], line 1
#     UnitPrice featur have a 550 values,there is no missing value
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## DiscountPct

# %%
DiscountPct feature  is  mean grater than std ,data is less variated.
DiscountPct featur have a 550 values,there is no missing value
DiscountPct feature  is  mean grater than std ,data is less variated.
DiscountPct feature 25% is 0 ,data lies below this value
DiscountPct feature 50% is 0,data lies below this value
DiscountPctfeature 75% is 0, data lies below this value
DiscountPct feature  0 minimum value
DiscountPct feature 0.20 maximum  value
# Out:
#   Cell In[11], line 1
#     DiscountPct feature  is  mean grater than std ,data is less variated.
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## PaymentMode

# %%
The PaymentMode feature contains 550 values with no missing values.
There are 4 unique payment modes in the dataset.
The most commonly used payment mode is UPI, appearing 156 times.
# Out:
#   Cell In[12], line 1
#     The PaymentMode feature contains 550 values with no missing values.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## OrderStatus

# %%
he OrderStatus feature contains 550 values with no missing values.
There are 3 unique order statuses in the dataset.
The most frequent order status is Delivered, appearing 457 times.
# Out:
#   Cell In[13], line 1
#     he OrderStatus feature contains 550 values with no missing values.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Rating

# %%
The Rating feature contains 550 values with no missing values.
customerID feature  is  mean grater than std ,data is less variated.
rating feature 25% is 3 ,data lies below this value
rating  feature 50% is 4,data lies below this value
rating feature 75% is  5, data lies below this value
The minimum rating is 1
the maximum rating is 5.
# Out:
#   Cell In[14], line 1
#     The Rating feature contains 550 values with no missing values.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## TotalSale

# %%
TotalSale featur have a 550 values,there is no missing value
TotalSale feature  is  mean grater than std ,data is less variated.
TotalSale feature 25% is 32630 ,data lies below this value
TotalSale feature 50% is 61669,data lies below this value
TotalSale feature 75% is 115376, data lies below this value
TotalSale feature  1136  minimum value
TotalSale feature  259640 maximum  value
# Out:
#   Cell In[15], line 1
#     TotalSale featur have a 550 values,there is no missing value
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## ExactSaleAmount

# %%
ExactSaleAmount featur have a 550 values,there is no missing value
ExactSale Amount feature  is  mean grater than std ,data is less variated.
ExactSale Amount feature 25% is 54992 ,data lies below this value
ExactSale  Amount feature 50% is 106387,data lies below this value
ExactSale Amount feature 75% is 244372, data lies below this value
ExactSale Amountfeature  292883  minimum value
ExactSale Amount feature  58421 maximum  value
# Out:
#   Cell In[16], line 1
#     ExactSaleAmount featur have a 550 values,there is no missing value
#                     ^
# SyntaxError: invalid syntax

# %%
df.isna().sum()#isna().sum is used to get the total count of missing values in each and every column
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# City             0
# Product          0
# Category         0
# Quantity         0
# UnitPrice        0
# DiscountPct     92
# PaymentMode      0
# OrderStatus      0
# Rating          38
# dtype: int64

# %%
df.duplicated().sum() # duplicated.sum() is used to get the count of duplicate rows
# Out:
# np.int64(0)

# %%
df["DiscountPct"] = df["DiscountPct"].fillna(0)

# %%
df["Rating"].fillna(df["Rating"].mean(),inplace=True)
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_27112\322049203.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Rating"].fillna(df["Rating"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# OrderID         0
# OrderDate       0
# CustomerID      0
# CustomerName    0
# City            0
# Product         0
# Category        0
# Quantity        0
# UnitPrice       0
# DiscountPct     0
# PaymentMode     0
# OrderStatus     0
# Rating          0
# dtype: int64

# %%
df.dtypes
# Out:
# OrderID           int64
# OrderDate        object
# CustomerID        int64
# CustomerName     object
# City             object
# Product          object
# Category         object
# Quantity          int64
# UnitPrice         int64
# DiscountPct     float64
# PaymentMode      object
# OrderStatus      object
# Rating          float64
# dtype: object

# %%
df["OrderDate"]= pd.to_datetime(df["OrderDate"])

# %%
df.dtypes
# Out:
# OrderID                  int64
# OrderDate       datetime64[ns]
# CustomerID               int64
# CustomerName            object
# City                    object
# Product                 object
# Category                object
# Quantity                 int64
# UnitPrice                int64
# DiscountPct            float64
# PaymentMode             object
# OrderStatus             object
# Rating                 float64
# dtype: object

# %%
df["TotalSale"]= df["Quantity"]*df["UnitPrice"]

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale
# 0     5.0       5852
# 1     5.0      27922
# 2     5.0     127128
# 3     3.0      61492
# ...

# %%
df["ExactSaleAmount"]=df["TotalSale"]*(1-df["DiscountPct"])

# %%
# feching columns
df["CustomerName"]
# Out:
# 0          Pooja
# 1      Siddharth
# 2          Megha
# 3         Ananya
# 4          Rohit
#          ...
# 545         Neha
# 546        Pooja
# 547        Megha
# 548       Manish
# 549        Megha
# Name: CustomerName, Length: 550, dtype: object

# %%
# feching multiply columns
df[["CustomerName","City","Product","Category"]]
# Out:
#     CustomerName       City     Product     Category
# 0          Pooja      Delhi      Laptop  Electronics
# 1      Siddharth     Mumbai      Mobile  Electronics
# 2          Megha  Hyderabad      Mobile  Electronics
# 3         Ananya  Hyderabad     Monitor  Electronics
# 4          Rohit    Chennai      Tablet  Electronics
# ..           ...        ...         ...          ...
# 545         Neha      Delhi     Monitor  Electronics
# 546        Pooja      Delhi        Desk    Furniture
# 547        Megha     Mumbai        Desk    Furniture
# 548       Manish    Chennai  Headphones  Accessories
# 549        Megha     Mumbai     Monitor  Electronics
#
# [550 rows x 4 columns]

# %%
# feching rowsbased
df[5:10]
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 5     1006 2024-01-02         221    Siddharth       Pune      Laptop
# 6     1007 2024-01-02         283         Riya  Bangalore        Desk
# 7     1008 2024-01-03         287        Kavya      Delhi        Desk
# 8     1009 2024-01-03         275         Riya  Hyderabad    Keyboard
# 9     1010 2024-01-03         275         Isha     Mumbai  Headphones
#
#       Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 5  Electronics         3       6444         0.00  Credit Card   Delivered
# 6    Furniture         2      54444         0.10          UPI   Cancelled
# 7    Furniture         3      59963         0.00  Credit Card   Delivered
# 8  Accessories         1      57218         0.15   Debit Card   Delivered
# 9  Accessories         1      25044         0.05          UPI   Delivered
#
#      Rating  TotalSale  ExactSaleAmount
# 5  3.000000      19332          19332.0
# ...

# %%
# boolean filtering
df[df["City"]=="Pune"]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName  City   Product     Category  \
# 5       1006 2024-01-02         221    Siddharth  Pune    Laptop  Electronics
# 10      1011 2024-01-04         288        Pooja  Pune    Mobile  Electronics
# 12      1013 2024-01-04         224        Kavya  Pune    Tablet  Electronics
# 18      1019 2024-01-06         230       Aditya  Pune      Desk    Furniture
# 21      1022 2024-01-07         264    Siddharth  Pune  Keyboard  Accessories
# ..       ...        ...         ...          ...   ...       ...          ...
# 526     1527 2024-06-22         269         Riya  Pune    Mobile  Electronics
# 532     1533 2024-06-24         219       Manish  Pune  Keyboard  Accessories
# 536     1537 2024-06-25         269       Aditya  Pune    Laptop  Electronics
# 537     1538 2024-06-26         204        Rahul  Pune     Chair    Furniture
# 543     1544 2024-06-28         232        Megha  Pune     Chair    Furniture
#
# ...

# %%
df[df["OrderStatus"]=="Delivered"]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City   Product  \
# 1       1002 2024-01-01         293    Siddharth     Mumbai    Mobile
# 3       1004 2024-01-01         272       Ananya  Hyderabad   Monitor
# 5       1006 2024-01-02         221    Siddharth       Pune    Laptop
# 7       1008 2024-01-03         287        Kavya      Delhi      Desk
# 8       1009 2024-01-03         275         Riya  Hyderabad  Keyboard
# ..       ...        ...         ...          ...        ...       ...
# 544     1545 2024-06-28         291       Aditya    Chennai     Mouse
# 545     1546 2024-06-28         284         Neha      Delhi   Monitor
# 546     1547 2024-06-29         224        Pooja      Delhi      Desk
# 547     1548 2024-06-29         212        Megha     Mumbai      Desk
# 549     1550 2024-06-30         235        Megha     Mumbai   Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
# multiple condtions
df[(df["City"]=="Pune") & (df["OrderStatus"]=="Delivered")]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName  City   Product     Category  \
# 5       1006 2024-01-02         221    Siddharth  Pune    Laptop  Electronics
# 10      1011 2024-01-04         288        Pooja  Pune    Mobile  Electronics
# 18      1019 2024-01-06         230       Aditya  Pune      Desk    Furniture
# 21      1022 2024-01-07         264    Siddharth  Pune  Keyboard  Accessories
# 22      1023 2024-01-08         260       Manish  Pune    Tablet  Electronics
# ..       ...        ...         ...          ...   ...       ...          ...
# 526     1527 2024-06-22         269         Riya  Pune    Mobile  Electronics
# 532     1533 2024-06-24         219       Manish  Pune  Keyboard  Accessories
# 536     1537 2024-06-25         269       Aditya  Pune    Laptop  Electronics
# 537     1538 2024-06-26         204        Rahul  Pune     Chair    Furniture
# 543     1544 2024-06-28         232        Megha  Pune     Chair    Furniture
#
# ...

# %%
# using isin() we can check for multiple filters/values in the spcified column
df[df["City"].isin(["Pune","Cheeni"])]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName  City   Product     Category  \
# 5       1006 2024-01-02         221    Siddharth  Pune    Laptop  Electronics
# 10      1011 2024-01-04         288        Pooja  Pune    Mobile  Electronics
# 12      1013 2024-01-04         224        Kavya  Pune    Tablet  Electronics
# 18      1019 2024-01-06         230       Aditya  Pune      Desk    Furniture
# 21      1022 2024-01-07         264    Siddharth  Pune  Keyboard  Accessories
# ..       ...        ...         ...          ...   ...       ...          ...
# 526     1527 2024-06-22         269         Riya  Pune    Mobile  Electronics
# 532     1533 2024-06-24         219       Manish  Pune  Keyboard  Accessories
# 536     1537 2024-06-25         269       Aditya  Pune    Laptop  Electronics
# 537     1538 2024-06-26         204        Rahul  Pune     Chair    Furniture
# 543     1544 2024-06-28         232        Megha  Pune     Chair    Furniture
#
# ...

# %%
df[df["TotalSale"].between(5000,15000)]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 0       1001 2024-01-01         252        Pooja      Delhi      Laptop
# 18      1019 2024-01-06         230       Aditya       Pune        Desk
# 21      1022 2024-01-07         264    Siddharth       Pune    Keyboard
# 58      1059 2024-01-20         202        Priya    Chennai     Monitor
# 94      1095 2024-01-31         240        Kunal      Delhi      Tablet
# 102     1103 2024-02-03         260        Rohit    Chennai  Headphones
# 110     1111 2024-02-06         209        Rahul    Chennai     Monitor
# 145     1146 2024-02-17         203    Siddharth      Delhi      Mobile
# 161     1162 2024-02-23         296        Pooja       Pune        Desk
# 168     1169 2024-02-25         236        Priya     Mumbai     Monitor
# 188     1189 2024-03-02         292    Siddharth      Delhi     Monitor
# 193     1194 2024-03-04         227        Aarav      Delhi    Keyboard
# ...

# %%
# sorting values-default is ascending order
df.sort_values("TotalSale")
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 507     1508 2024-06-16         278        Aarav  Hyderabad     Monitor
# 330     1331 2024-04-18         221        Pooja  Bangalore       Mouse
# 107     1108 2024-02-05         265        Rahul  Hyderabad      Tablet
# 294     1295 2024-04-06         237         Riya      Delhi      Laptop
# 198     1199 2024-03-06         272       Nikita  Bangalore        Desk
# ..       ...        ...         ...          ...        ...         ...
# 464     1465 2024-06-01         299        Rahul      Delhi       Mouse
# 420     1421 2024-05-18         257         Neha    Chennai       Mouse
# 40      1041 2024-01-14         262       Aditya    Chennai      Laptop
# 250     1251 2024-03-23         211       Aditya    Chennai     Monitor
# 366     1367 2024-04-30         244        Kunal       Pune  Headphones
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
df.sort_values("TotalSale",ascending=False)
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 366     1367 2024-04-30         244        Kunal       Pune  Headphones
# 250     1251 2024-03-23         211       Aditya    Chennai     Monitor
# 40      1041 2024-01-14         262       Aditya    Chennai      Laptop
# 420     1421 2024-05-18         257         Neha    Chennai       Mouse
# 464     1465 2024-06-01         299        Rahul      Delhi       Mouse
# ..       ...        ...         ...          ...        ...         ...
# 198     1199 2024-03-06         272       Nikita  Bangalore        Desk
# 294     1295 2024-04-06         237         Riya      Delhi      Laptop
# 107     1108 2024-02-05         265        Rahul  Hyderabad      Tablet
# 330     1331 2024-04-18         221        Pooja  Bangalore       Mouse
# 507     1508 2024-06-16         278        Aarav  Hyderabad     Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
df.sort_values(["City","TotalSale"],ascending=[True,False])
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 201     1202 2024-03-07         262        Sneha  Bangalore  Headphones
# 184     1185 2024-03-01         284        Aarav  Bangalore       Chair
# 405     1406 2024-05-13         233       Aditya  Bangalore  Headphones
# 528     1529 2024-06-23         234         Isha  Bangalore      Laptop
# 153     1154 2024-02-20         215        Kavya  Bangalore       Chair
# ..       ...        ...         ...          ...        ...         ...
# 497     1498 2024-06-12         222        Priya       Pune       Mouse
# 460     1461 2024-05-31         206       Aditya       Pune        Desk
# 21      1022 2024-01-07         264    Siddharth       Pune    Keyboard
# 413     1414 2024-05-16         299        Megha       Pune    Keyboard
# 356     1357 2024-04-27         297         Neha       Pune        Desk
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
##apply()-
def discount_label(x):
    if x==0:
        return "No Discount"
    elif x<=0.10:
        return "Low Discount"
    else:
        return "High Discount"
df["DiscountCategory"] = df["DiscountPct"].apply(discount_label)

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale  ExactSaleAmount DiscountCategory
# 0     5.0       5852           5266.8     Low Discount
# ...

# %%
df["City"].unique()# unique() is used to get the unique value in the column.
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Chennai', 'Pune', 'Bangalore'],
#       dtype=object)

# %%
df["City"].nunique()# nunique() is used to get the number of unique values in the columns
# Out:
# 6

# %%
df["City"].value_counts()#value_count() is used to get the total countfor each unique value in the column
# Out:
# City
# Chennai      102
# Pune          97
# Delhi         95
# Bangalore     93
# Mumbai        82
# Hyderabad     81
# Name: count, dtype: int64

# %%
# map()- maps the specified value to the given
city_region={
    "Pune":"West",
    "Mumbai":"West",
    "Delhi":"North",
    "Banglore":"South",
    "Hyderabad":"South",
    "Chennai":"South"}
df["Region"]=df["City"].map(city_region)

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale  ExactSaleAmount DiscountCategory Region
# ...

# %%
#Group by in pandas
#groupby(Grouping_column)metricColumn].Aggregatefunction
#Aggregate function:
'''
1.mean()=Average
2.min()-minimum vakue
3.sum()-total
4.max()-maximum value
5.count()=TotalCount
'''
df.groupby("City")["TotalSale"].mean()
# Out:
# City
# Bangalore    85640.053763
# Chennai      84318.117647
# Delhi        81131.136842
# Hyderabad    80319.061728
# Mumbai       80938.378049
# Pune         76043.453608
# Name: TotalSale, dtype: float64

# %%
df.groupby("City")["TotalSale"].sum()
# Out:
# City
# Bangalore    7964525
# Chennai      8600448
# Delhi        7707458
# Hyderabad    6505844
# Mumbai       6636947
# Pune         7376215
# Name: TotalSale, dtype: int64

# %%
df.groupby("City")["TotalSale"].agg(["mean","sum","min","max","count"])
# Out:
#                    mean      sum   min     max  count
# City
# Bangalore  85640.053763  7964525  1682  220928     93
# Chennai    84318.117647  8600448  3340  253240    102
# Delhi      81131.136842  7707458  2844  246940     95
# Hyderabad  80319.061728  6505844  1136  244372     81
# Mumbai     80938.378049  6636947  6636  244432     82
# Pune       76043.453608  7376215  3057  259640     97

# %%
df.groupby(["City","Product"])["TotalSale"].mean()
# Out:
# City       Product
# Bangalore  Chair         105276.214286
#            Desk           68806.750000
#            Headphones    121966.000000
#            Keyboard       96878.250000
#            Laptop         84787.866667
#            Mobile         96194.111111
#            Monitor        68073.125000
#            Mouse          66327.666667
#            Tablet         63512.400000
# Chennai    Chair          37185.625000
#            Desk           90678.857143
#            Headphones    127155.076923
#            Keyboard       78241.000000
#            Laptop         92010.384615
#            Mobile         59297.200000
#            Monitor        84172.000000
#            Mouse          74462.812500
#            Tablet         90787.454545
# Delhi      Chair          71155.357143
#            Desk           87703.454545
#            Headphones     90062.000000
#            Keyboard       87877.300000
#            Laptop         52137.333333
# ...

# %%
#Named Aggregations
df.groupby("Category").agg(AverageTotalRevenue =("ExactSaleAmount","mean"),
                           TotalRevenue=("ExactSaleAmount","sum"),                
                           OrderCount=("OrderID","count"))
# Out:
#              AverageTotalRevenue  TotalRevenue  OrderCount
# Category
# Accessories         84341.832865   15012846.25         178
# Electronics         71544.285802   17385261.45         243
# Furniture           66304.284884    8553252.75         129

# %%
df[df["PaymentMode"]=="UPI"].groupby("City")["TotalSale"].sum()#groping base on conditions 
#condititon.groupby().aggregatefunction()
# Out:
# City
# Bangalore    2093141
# Chennai      1573943
# Delhi        1837064
# Hyderabad    1686632
# Mumbai       2122856
# Pune         2305557
# Name: TotalSale, dtype: int64

# %%
df.groupby("City").filter(lambda x:x["TotalSale"].sum()>80000)
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 0       1001 2024-01-01         252        Pooja      Delhi      Laptop
# 1       1002 2024-01-01         293    Siddharth     Mumbai      Mobile
# 2       1003 2024-01-01         215        Megha  Hyderabad      Mobile
# 3       1004 2024-01-01         272       Ananya  Hyderabad     Monitor
# 4       1005 2024-01-02         261        Rohit    Chennai      Tablet
# ..       ...        ...         ...          ...        ...         ...
# 545     1546 2024-06-28         284         Neha      Delhi     Monitor
# 546     1547 2024-06-29         224        Pooja      Delhi        Desk
# 547     1548 2024-06-29         212        Megha     Mumbai        Desk
# 548     1549 2024-06-29         250       Manish    Chennai  Headphones
# 549     1550 2024-06-30         235        Megha     Mumbai     Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
average_totalSale_city=df.groupby("City")["TotalSale"].mean()
average_totalSale_city.head()
# Out:
# City
# Bangalore    85640.053763
# Chennai      84318.117647
# Delhi        81131.136842
# Hyderabad    80319.061728
# Mumbai       80938.378049
# Name: TotalSale, dtype: float64

# %%
average_totalSale_city[average_totalSale_city>84000]
# Out:
# City
# Bangalore    85640.053763
# Chennai      84318.117647
# Name: TotalSale, dtype: float64

# %%
df["year"]=df["OrderDate"].dt.year#.dt.year extracts yearfrom the mentioned date
df["Month"]=df["OrderDate"].dt.month#.dt.month extracts month from the mentioned date
df["Day"]=df["OrderDate"].dt.day#dt.day extracts the day from the mentioned adte
df["MonthName"]=df["OrderDate"].dt.month_name()# extract the month name for the mentioned date
df["DayName"]=df["OrderDate"].dt.day_name()#extract day_name for the given date
df["Quarter"]=df["OrderDate"].dt.quarter#.dt.quarter the quarter for the mentioned date

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct  ... TotalSale  \
# 0  Electronics         1       5852         0.10  ...      5852
# 1  Electronics         1      27922         0.05  ...     27922
# 2  Electronics         3      42376         0.15  ...    127128
# 3  Electronics         1      61492         0.20  ...     61492
# 4  Electronics         1      18306         0.15  ...     18306
#
#   ExactSaleAmount  DiscountCategory  Region  year Month Day  MonthName  \
# 0          5266.8      Low Discount   North  2024     1   1    January
# ...

# %%
df.groupby("MonthName")["ExactSaleAmount"].mean()
# Out:
# MonthName
# April       71531.934066
# February    76474.353448
# January     65742.672105
# June        87100.605114
# March       71164.181579
# May         75720.014362
# Name: ExactSaleAmount, dtype: float64

# %%
df.groupby("Quarter")["ExactSaleAmount"].sum()
# Out:
# Quarter
# 1    19659419.85
# 2    21291940.60
# Name: ExactSaleAmount, dtype: float64

# %%
df.groupby("DayName")["ExactSaleAmount"].sum()
# Out:
# DayName
# Friday       5713486.50
# Monday       5783726.45
# Saturday     5910951.15
# Sunday       6106891.55
# Thursday     5626392.55
# Tuesday      5389395.80
# Wednesday    6420516.45
# Name: ExactSaleAmount, dtype: float64

# %%
df.groupby("TotalSale")["ExactSaleAmount"].mean()
# Out:
# TotalSale
# 1136        1136.00
# 1682        1513.80
# 2690        2690.00
# 2844        2844.00
# 3021        2869.95
#             ...
# 246940    222246.00
# 250568    212982.80
# 251456    226310.40
# 253240    227916.00
# 259640    233676.00
# Name: ExactSaleAmount, Length: 549, dtype: float64

# %%
plt.hist(df["Quantity"])
plt.title("quantity distribution using histogram")
plt.xlabel("Quantity")
plt.ylabel("frequency")
plt.show()

# %%
the distribution show many products have order quantity arount 1 to 2 and are few products with quantity  followed 3. 
so we can say customer usally order 1 or 2 quantitys
# Out:
#   Cell In[62], line 1
#     the distribution show many products have order quantity arount 1 to 2 and are few products with quantity  followed 3.
#         ^
# SyntaxError: invalid syntax

# %%
plt.hist(df["UnitPrice"],edgecolor="black")
plt.title("histogram of unit price distribution")
plt.xlabel("unit price")
plt.ylabel("frequency count")
plt.show()

# %%
The histogram represents the distribution of unit prices across products. 
The prices are spread over a wide range, indicating good price variation in the dataset.
Most products are concentrated in the mid-price range (around 25,000–35,000),
showing that this is the most common pricing segment.
# Out:
#   Cell In[72], line 3
#     Most products are concentrated in the mid-price range (around 25,000–35,000),
#                                                                         ^
# SyntaxError: invalid character '–' (U+2013)

# %%
#DiscountPct
plt.hist(df["DiscountPct"])
plt.title("histogram of DiscountPct distribution")
plt.xlabel("discount percentage ")
plt.ylabel("frequency ")
plt.show()

# %%
#in this discount distribution show the higthes pct in 0.100 to o.125

# %%
#rating
plt.hist(df["Rating"])
plt.title("histogram of rating")
plt.xlabel("rating ")
plt.ylabel("frequency ")
plt.show()

# %%
in this  rating histogram  show the higesr rating 4.0 and lowest rating 1.0 in 2.5 
there is missing  rating show in histogram
# Out:
#   Cell In[77], line 1
#     in this  rating histogram  show the higesr rating 4.0 and lowest rating 1.0 in 2.5
#     ^
# SyntaxError: invalid syntax

# %%
plt.hist(df["CustomerID"])
plt.title("histogram of customerId")
plt.xlabel("CustomerID")
plt.ylabel("frequency ")
plt.show()

# %%
sns.countplot(x=df["City"],data=df)
plt.title("count plot for city")
plt.xlabel("products")
plt.xticks(rotation = 45)
plt.show()

# %%
in this countplot show higst prouct show in chennai  there count is 100 and lowest product 
show in mumbai and hyderabad there count is about 80
# Out:
#   Cell In[80], line 1
#     in this countplot show higst prouct show in chennai  there count is 100 and lowest product
#     ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x=df["Product"],data=df)
plt.title("count plot for product")
plt.xlabel("products")
plt.xticks(rotation = 45)
plt.show()

# %%
the Distribution show tablet and chair have  higest count upto 65 
laptop,mobile,keyboard,Headphones have same count 58
desk have 60 count and mouse have 63 count
# Out:
#   Cell In[82], line 1
#     the Distribution show tablet and chair have  higest count upto 65
#         ^
# SyntaxError: invalid syntax

# %%
sns.countplot(y=df["Product"],data=df)
plt.title("count plot for product")
plt.xlabel("products")
plt.yticks(rotation = 45)
plt.show()

# %%
sns.countplot(x=df["Product"],hue="City",data=df)
plt.title("city wise product split")
plt.xlabel("Product")
plt.xticks(rotation=90)
plt.show()

# %%
the distribution  show city wise product there pune is more product sale  keyboard as compare to to other city,chennai have most product sale mouse.
# Out:
#   Cell In[85], line 1
#     the distribution  show city wise product there pune is more product sale  keyboard as compare to to other city,chennai have most product sale mouse.
#         ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x=df["Category"],hue="Quantity",data=df)
plt.title("Quantity wise category split")
plt.xlabel("category")
plt.xticks(rotation=45)
plt.show()

# %%
in this countplot show  3 category most quentity show in electronics.

# %%
sns.countplot(x=df["City"],hue="OrderStatus",data=df)
plt.title("city wise orderstatus split")
plt.xlabel("OrderStatus")
plt.xticks(rotation=45)
plt.show()

# %%
#in this countplot show the chennai have most order delivereaqwed ,delhi and bangalore have show  less returned order

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.countplot(x=df["City"],hue="Category",data=df)
plt.title("category wise city split")
plt.xlabel("Categoty")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=df["Rating"],hue="Category",data=df)
plt.title("category wise Rating split")
plt.xlabel("Rating")
plt.xticks(rotation=45)
plt.show()

# %%
the distribution  show electronices,accessories ,funiture have higst rating 4 as compare to other
# Out:
#   Cell In[90], line 1
#     the distribution  show electronices,accessories ,funiture have higst rating 4 as compare to other
#         ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x=df["PaymentMode"],hue="Category",data=df)
plt.title("category wise paymentMode split")
plt.xlabel("paymentMode")
plt.xticks(rotation=90)
plt.show()

# %%
the distribution  show many pepole use upi paymentmode methos as compare to cash ,debit car, credit card paymentmode
# Out:
#   Cell In[91], line 1
#     the distribution  show many pepole use upi paymentmode methos as compare to cash ,debit car, credit card paymentmode
#         ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x=df["Rating"],hue="Product",data=df)
plt.title("product wise rating split")
plt.xlabel("Product")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=df["City"],hue="PaymentMode",data=df)
plt.title(" paymentMode wise city split")
plt.xlabel("paymentMode")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["City"],hue="Category",data=df)
plt.title("category wise city split")
plt.xlabel("Category ")
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.countplot(x=df["City"],hue="DiscountPct",data=df)
plt.title("Discountpct wise city split")
plt.xlabel("DiscountPct")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["City"],hue="PaymentMode",data=df)
plt.title("paymentMode wise city split")
plt.xlabel("PaymentMode")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["City"],hue="PaymentMode",data=df)
plt.title("paymentMode wise city split")
plt.xlabel("PaymentMode")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["City"],hue="Rating",data=df)
plt.title("Rating wise city split")
plt.xlabel(" Rating")
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.countplot(x=df["Category"],data=df)
plt.title("count plot for Category")
plt.xlabel("Category")
plt.xticks(rotation = 45)
plt.show()

# %%
the discription show the higst count electronics upto 240 then accessories show 180 count and furniture show lowest count upto 130.
# Out:
#   Cell In[102], line 1
#     the discription show the higst count electronics upto 240 then accessories show 180 count and furniture show lowest count upto 130.
#         ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x=df["CustomerName"],data=df)
plt.title("count plot for customername")
plt.xlabel("CustomerName")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=df["PaymentMode"],data=df)
plt.title("count plot for paymentmode")
plt.xlabel("Paymentmode")
plt.xticks(rotation=90)
plt.show()

# %%
the  discription show mostly pepole use upi payment mode there count is 150 ,the cash count is 140,credit card count is 130, 
and some pepole use debit card

# %%
sns.countplot(x=df["OrderStatus"],data=df)
plt.title("count plot for OrderStatus")
plt.xlabel("orderstatus")
plt.show()

# %%
the count plot show most most order delivered , some order is cancelled and minimum order is retuned
# Out:
#   Cell In[104], line 1
#     the count plot show most most order delivered , some order is cancelled and minimum order is retuned
#         ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
plt.scatter(df["Quantity"],df["ExactSaleAmount"])
plt.xlabel("Quantity")
plt.ylabel("ExactSaleAmount")
plt.title("Quantity wise sale amount")
plt.show()

# %%
the visualzation shows that the relanship between the two features Quantity and exteractsaleamount is positive as the quantity incress 
so does the Exact sale amount. there are few orders with 3 and 4 quantity which incress the sale amount for these quantites.
# Out:
#   Cell In[107], line 1
#     the visualzation shows that the relanship between the two features Quantity and exteractsaleamount is positive as the quantity incress
#         ^
# SyntaxError: invalid syntax

# %%
plt.scatter(df["Quantity"],df["UnitPrice"])
plt.title("Quantity wise unit price")
plt.xlabel("Quantity")
plt.ylabel("Unitprice")
plt.show()

# %%
there  is no relanship between them

# %%
plt.scatter(df["Rating"],df["UnitPrice"])
plt.title("rating wisw Unitprice")
plt.xlabel("rating")
plt.ylabel("unitprice")
plt.show()

# %%
there is no relanship between them.

# %%
plt.scatter(df["Quantity"],df["TotalSale"])
plt.title("Quantity  wisw totalsale")
plt.xlabel("Quantity")
plt.ylabel("totalsale")
plt.show()

# %%
the visualzation shows that the relanship between the two features Quantity and totalsale amount is positive as the quantity incress 
so does the totalsale. there are few orders with 3 and 4 quantity which incress the sale amount for these quantites.

# %%
plt.scatter(df["UnitPrice"],df["DiscountPct"])
plt.title("Unitprice wisw discountpct")
plt.xlabel("Unitprice")
plt.ylabel("dicountpct")
plt.show()

# %%
there is no relanship between them

# %%
plt.scatter(df["UnitPrice"],df["Rating"])
plt.title("Unitprice wise rating")
plt.xlabel("Unitprice")
plt.ylabel("rating")
plt.show()

# %%
there is no relanship between them

# %%
plt.scatter(df["UnitPrice"],df["TotalSale"])
plt.title("Unitprice wise Totalsale")
plt.xlabel("Unitprice")
plt.ylabel("totalsale")
plt.show()

# %%
the visualization show that the relanship between the two features  unitprice and totalsale is upword side is positive .
if unitprice incress totalsale also incress.

# %%
plt.scatter(df["DiscountPct"],df["Quantity"])
plt.title("dicountpct wise quantity")
plt.xlabel("DiscountPct")
plt.ylabel("Quantity")
plt.show()

# %%
there is no relanship between them

# %%
plt.scatter(df["DiscountPct"],df["UnitPrice"])
plt.title("DiscountPct wise Unitprice")
plt.xlabel("Discountpct")
plt.ylabel("UnitPrice")
plt.show()

# %%
there is no relanship betwwn discountpact and unitprice.

# %%
plt.scatter(df["DiscountPct"],df["TotalSale"])
plt.title("Discount wise TotalSale")
plt.xlabel("DiscountPct")
plt.ylabel("TotalSale")
plt.show()

# %%
the visualization show there if discountpct  is incress  total sale is also incress and decress.

# %%
plt.scatter(df["DiscountPct"],df["ExactSaleAmount"])
plt.title("DiscountPct wise ExactSaleAmount")
plt.xlabel("DiscountPct")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
the visulazation show if discountpct is incres the exact sale amount alos increasa and decreases

# %%
plt.scatter(df["Rating"],df["Quantity"])
plt.title("rating wise Quantity")
plt.xlabel("Rating")
plt.ylabel("Quantity")
plt.show()

# %%
there is no relanship between rating and Quantity.

# %%
plt.scatter(df["TotalSale"],df["ExactSaleAmount"])
plt.title("Totalsale wise Exactsaleamount")
plt.xlabel("TotalSale")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
the visualization show there is two features totalsale and exact sale amount is positive .if totalsale incress exact sale amount also incress

# %%
plt.scatter(df["UnitPrice"],df["ExactSaleAmount"])
plt.title("uniptprice wise Exactsaleamount")
plt.xlabel("Unitprice")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
the visualization show  the two features unitprice and exact sale amount.if unitprice incresss Exact sale amount aslo incress

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.boxplot(x="Quantity",y="UnitPrice",data=df)
plt.title("product wise exact sales")
plt.xlabel("Quantity")
plt.ylabel("Unitprice")
plt.xticks(rotation=90)
plt.show()

# %%
The visualization show Quantity 1,3 and 4 have same median  and quantity 2 have higer median.

# %%
sns.boxplot(x="Product",y="ExactSaleAmount",data=df)
plt.title("product wise exact sales")
plt.xlabel("product")
plt.ylabel("ExactSaleAmount")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization indicates that the products like headphones,laptops,tablet have higer median sale,where as the product like  mouse,
chair ,monitar have lower medain sales.also the sales for headphones,keyboard,tablet have no outliers which indicates there are no
such orders deriving the sale amount to higer values.

# %%
sns.boxplot(x="Product",y="City",data=df)
plt.title("product wise city")
plt.xlabel("product")
plt.ylabel("city")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization indicates  the product laptop,mobile,monitar,tablet have a high median sale ,where desk,keyboared ,
chair,mouse have a lower median city,headphone have a same median

# %%
sns.boxplot(x="PaymentMode",y="UnitPrice",data=df)
plt.title("paymentmode wise unitprice")
plt.xlabel("Paymentmode")
plt.ylabel("unitprice")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization show  the paymentmode upi,debit-card have as high median unitprice also cash and credit card have low median unitprice

# %%
sns.boxplot(x="Category",y="City",data=df)
plt.title("category wise city")
plt.xlabel("Category")
plt.ylabel("City")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization show the accessories have a high media city ,where as the electronices,furniture have a low median city

# %%
sns.boxplot(x="City",y="Quantity",data=df)
plt.title("city wise Quantity ")
plt.xlabel("City")
plt.ylabel("Quantity")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization show the city  show mumbai,hyderabad ,pune have same media but delhi have a lower median Quantityt

# %%
sns.boxplot(x="Product",y="UnitPrice",data=df)
plt.title("product wise UnitPrice ")
plt.xlabel("City")
plt.ylabel("Unitprice")
plt.xticks(rotation=90)
plt.show()

# %%
the boxplot indicate  keyboard,mobile,headphones have a high median unitprice and tablet,desk,mouse have a loer median unitprice ,monitar ,
chair have a same median unitprice followed by other

# %%
sns.boxplot(x="Product",y="DiscountPct",data=df)
plt.title("product wise DiscountPct")
plt.xlabel("product")
plt.ylabel("DiscountPct")
plt.xticks(rotation=90)
plt.show()

# %%
the visulaization indicate the mobile,monitar,keyboared have a high median discountpct ,where  as a tablet,headphones,chair have a lower median sale and laptop,
desk,mouse have a same median discountpct

# %%
sns.boxplot(x="PaymentMode",y="Product",data=df)
plt.title("paymentmode wise product")
plt.xlabel("paymentmode")
plt.ylabel("product")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization show the upi,and credit card have a high median product and cash and debit card have a same median followed by other.

# %%
sns.boxplot(x="Category",y="UnitPrice",data=df)
plt.title("category wise unitprice")
plt.xlabel("category")
plt.ylabel("unitprice")
plt.xticks(rotation=90)
plt.show()

# %%
the visulization show  theaccessories have a high median unitprice ,where as a electronices and furniture have a lower mdeian unit price.

# %%
sns.boxplot(x="Product",y="TotalSale",data=df)
plt.title("product wise totalsale")
plt.xlabel("product")
plt.ylabel("TotalSale")
plt.xticks(rotation=90)
plt.show()

# %%
the visualization indicates that the products like headphones,laptops,tablet have higer median sale,where as the product like  mouse,
chair ,monitar have lower medain sales.also the sales for headphones,keyboard,tablet have no outliers which indicates there are no
such orders deriving the sale amount to higer values.

# %%
sns.boxplot(x="",y="",data=df)
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.boxplot(x="DiscountPct",y="Quantity",data=df)
plt.title("distribution of discountpct compare to rating")
plt.xlabel(" Quantity")
plt.ylabel("rating")
plt.show()

# %%
the visul
# Out:
#   Cell In[94], line 1
#     the visul
#         ^
# SyntaxError: invalid syntax

# %%
sns.boxplot(x="PaymentMode",y="ExactSaleAmount",data=df)
plt.title("Distribution  of the  payment mode compare to EaxctSaleAmount ")
plt.xlabel("payment mode")
plt.ylabel("ExactSaleAmount")
plt.xticks(rotation=90)
plt.show()

# %%
the visulalization show median is credit card ,upi,cash,debit card have less median ac comare to credit card,cash have no outlier there are no
such orders deriving the sale amount to higer values. upi,debit card and credit card have outlier.

# %%
sns.regplot(x="UnitPrice",y="ExactSaleAmount",data=df)
plt.title("Distribution of unitprice compare to ExactsaleAmount")
plt.xlabel("UnitPrice")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
the visulization here indicates an upward trend in unit price ans Exact sale Amount feature,which means that there's 
 the exact a positive relanship as the unit price incress the exact sale amount also incress

# %%
sns.regplot(x="DiscountPct",y="ExactSaleAmount",data=df)
plt.title("Distribution of discountpct comapre to Exactsaleamount")
plt.xlabel("DiscounPct")
plt.ylabel("EactsaleAmount")
plt.show()

# %%
the visulization here indicates an downwoed trend in discountpct ans Exact sale Amount feature,which means that there's 
the exact a negative relanship as the unit price decress the exact sale amount also decress.

# %%
sns.regplot(x="TotalSale",y="Rating",data=df)
plt.title("distribution of totalsale compare to rating")
plt.xlabel("TotalSale")
plt.ylabel("Rating")
plt.show()

# %%
the visulization here indicate an upward trend in totalsale and rating feature which means ,the exact positive relanship as the unit price
incress the exact sale amount also incress.

# %%
sns.regplot(x="Quantity",y="ExactSaleAmount",data=df)
plt.title("Distribution of discountpct comapre to Exactsaleamount")
plt.xlabel("Quantity")
plt.ylabel("ExactsaleAmount")
plt.show()

# %%
the visulization  here indicate an upward trend in totalsale and rating feature which means ,
the exact positive relanship as the unit price incress the exact sale amount als0 incress

# %%
sns.regplot(x="TotalSale",y="ExactSaleAmount",data=df)
plt.title("distribution of Discountcategory compare to exactsaleamount")
plt.xlabel("TotalSale")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
the visulization here  indicate an upword trend in discountcategory  and exactsaleamount feature which means,
the exact positive relanship as the unit price incress the exact sale amount also incress.

# %%
the visulization  here indicate an upward trend in totalsale and rating feature which means ,
the exact positive relanship as the unit price incress the exact sale amount also incress

# %%
sns.regplot(x="DiscountPct",y="OrderID",data=df)
plt.title("distribution of Discountcategory compare to exactsaleamount")
plt.xlabel("TotalSale")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
sns.scatterplot(x="Quantity",y="ExactSaleAmount",hue="PaymentMode",data=df)
plt.title("scatterplot for analysing quantity and exact sale amount with respect to pay mode")
plt.xlabel("Quantity")
plt.ylabel("Exactsaleamount")
plt.show()

# %%
The visulization show  in first quantity  most cash  are use in 1.5 most upi payment use,2.5  cash are use,in 4.0 most pepole use debit card,
the most op peple use cash ,debit card and credit card.
the visulization show peple use cash ,debit

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="DiscountPct",y="ExactSaleAmount",hue="Quantity",data=df)
plt.title("the Scatterplot show Discountpct with exact sale amount  with respect Quantity")
plt.xlabel("DiscountPct")
plt.ylabel("ExactSaleAmount")
plt.show()

# %%
The visualization show in if no discount quantity is equal  as compare to other in o.5 dicount there is 3 and 4 quantity is grater, in 0.10 discount
there is 1,2,3 quantity is grater,in 0.15 discount there is 3,4 quantity is more, in 0.20 discount  3 and 4 is more as compare to other

# %%
The visualization indicates there is no certain trend between discount percentage and exact sale amount ,but we can say 
if the discount is higher the sale amount gets lowered compared to other discount percentages.
There nit a single quantity dominating the discount,
but higher discounts are usuaaly given to higher discounts are usually given to higher quanties.Lower quantites get discount arounfd 5%-10%

# %%
sns.scatterplot(x="Quantity",y="TotalSale",hue="PaymentMode",data=df)
plt.title("scatterplot for analysing quantity and exact sale amount with respect to pay mode")
plt.xlabel("Quantity")
plt.ylabel("Exactsaleamount")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="DiscountPct",y="UnitPrice",hue="Product",data=df)
plt.title("scatterplot for analysing Discountpct and unitprice with respect product")
plt.xlabel("Discountpct")
plt.ylabel("UnitPrice")
plt.show()

# %%
The visualization indicates there is no certain trend between discount percentage and exact sale amount ,but we can say 
if the discount is higher the sale amount gets lowered compared to other discount percentages.
There nit a single quantity dominating the discount,
but higher discounts are usuaaly given to higher discounts are usually given to higher quanties.Lower quantites get discount arounfd 5%-10%

# %%
sns.scatterplot(x="TotalSale",y="UnitPrice",hue="OrderStatus",data=df)
plt.title("scatterplot for analysing TotalSale and unitprice with respaect orderstatus")
plt.xlabel("Totalsale")
plt.ylabel("UnitPrice")
plt.show()

# %%
the visualization indicate

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="Product",y="ExactSaleAmount",hue="PaymentMode",data=df)
plt.title("the boxplot distribution  shoe product with Exactsaleamount with respect paymentmode")
plt.xlabel("Product")
plt.ylabel("Exactsaleamount")
plt.show()

# %%
in this Visualazation indicate  laptop show most of use credit card folloed by cash,
in mobile most of use cash payment mode followed by credit card,
in monitor use most upi payment mode, in tablet most of use upi, in desk product most of use credit card ,debit card, in keyboard use most cash as compare to other
headphone use credit card ,chair most  use credit card, in mouse use upi payment mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.pairplot(df[["Quantity","UnitPrice","DiscountPct","ExactSaleAmount"]])

# %%
the visualization indicate  the  quantity  effect show on Exactsaleamount is incress, in second block exactsaleamount is incress,in thried block no exact changes show,
in fourth block discount pct effct show on exactsaleamount is incress

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSaleAmount   550 non-null    float64
#  15  DiscountCategory  550 non-null    object
# ...

# %%
sns.pairplot(df[["Quantity","DiscountPct","UnitPrice","Rating"]])

# %%
the visualization indicate in first block Quantity effect show on unitprice is incress,in second block there is not discountpct there is not effect on unit price,
in thried block there is no relanshipbetween them  ,in fourth block unitprice is incress then rating also incress.

# %%
sns.pairplot(df[["","DiscountPct","TotalSale"]])
