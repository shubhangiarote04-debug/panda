# %%
import pandas as pd

# %%
#1. Load the dataset into a Pandas DataFrame.
df = pd.read_csv("C:\\Users\\PRASHANT\\Downloads\\edtech_student_learning_data.csv")

# %%
#2. Display the first 10 records of the dataset.
df.head(10)
# Out:
#    student_id student_name  gender       city enrollment_date          course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25   Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29         AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05    Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09         AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03   Generative AI
# 5        1006    Student_6  Female       Pune      2024-09-18   Generative AI
# 6        1007    Student_7    Male     Mumbai      2024-02-22  Data Analytics
# 7        1008    Student_8    Male    Chennai      2024-07-23    Data Science
# 8        1009    Student_9    Male     Mumbai      2024-05-05         AI & ML
# 9        1010   Student_10  Female      Delhi      2024-08-22  Data Analytics
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# ...

# %%
#3. Display the last 5 records of the dataset.
df.tail(5)
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 500              84                84             58           2.2
# ...

# %%
#4. Check the shape of the dataset.
df.shape
# Out:
# (505, 18)

# %%
#5. Display all column names along with their data types.
df.dtypes
# Out:
# student_id             int64
# student_name          object
# gender                object
# city                  object
# enrollment_date       object
# course                object
# batch_type            object
# total_sessions         int64
# sessions_attended      int64
# avg_quiz_score         int64
# assignment_score       int64
# project_score          int64
# final_rating         float64
# learning_hours         int64
# placement_status      object
# feedback_score         int64
# attendance_pct       float64
# salary_offered       float64
# dtype: object

# %%
#6. Generate summary statistics for all numerical columns.
df.describe()
# Out:
#         student_id  total_sessions  sessions_attended  avg_quiz_score  \
# count   505.000000           505.0         505.000000      505.000000
# mean   1251.015842           120.0          88.102970       69.601980
# std     144.242011             0.0          17.087232       17.137226
# min    1001.000000           120.0          60.000000       40.000000
# 25%    1127.000000           120.0          73.000000       56.000000
# 50%    1251.000000           120.0          88.000000       69.000000
# 75%    1376.000000           120.0         103.000000       84.000000
# max    1500.000000           120.0         119.000000       99.000000
#
#        assignment_score  project_score  final_rating  learning_hours  \
# count        505.000000     505.000000    477.000000      505.000000
# mean          71.984158      75.287129      3.535220       22.128713
# std           15.777337      14.678794      0.862365        9.924180
# ...

# %%
df.describe(include="all")
# Out:
#          student_id student_name  gender       city enrollment_date  \
# count    505.000000          505     505        505             505
# unique          NaN          500       2          6             269
# top             NaN  Student_210  Female  Hyderabad      2024-04-20
# freq            NaN            2     259        100               7
# mean    1251.015842          NaN     NaN        NaN             NaN
# std      144.242011          NaN     NaN        NaN             NaN
# min     1001.000000          NaN     NaN        NaN             NaN
# 25%     1127.000000          NaN     NaN        NaN             NaN
# 50%     1251.000000          NaN     NaN        NaN             NaN
# 75%     1376.000000          NaN     NaN        NaN             NaN
# max     1500.000000          NaN     NaN        NaN             NaN
#
#                 course batch_type  total_sessions  sessions_attended  \
# count              505        505           505.0         505.000000
# ...

# %% [markdown]
# ## student_id

# %% [markdown]
# student_id have **505**value,there is no missng value
# student_id mean grater than std,thats mean data is strong and stable
# 25% of data **1127** data lies below this value
# 50% of data **1251** data lies below this value
# 75% of data **1376** data lies below this vallue
# student_id min value is 1001,and max value is 1500

# %% [markdown]
# ## student_name

# %% [markdown]
# student_name have **505**value,there is no missng value
# there are **500** unique value in student_name column
# student_210 indicates most frequent value in that column
# frequent value 2 number of time the value have been repeated

# %% [markdown]
# ## city

# %% [markdown]
# city have **505**value,there is no missng value
# there are **6** unique value in city column
# Hyderabad indicates most frequent value in that column
# frequent value **100** number of time the value have been repeated

# %% [markdown]
# ## gender

# %% [markdown]
# gender have **505**value,there is no missng value
# there are **2** unique value in gender column
# Female indicates most frequent value in that column
# frequent value **259** number of time the value have been repeated

# %% [markdown]
# ## endrollment_date

# %% [markdown]
# endrollment_datehave **505**value,there is no missng value
# there are **269** unique value in gender column
# Data Analytics indicates most frequent value in that column
# frequent value **7** number of time the value have been repeated

# %% [markdown]
# ## course

# %% [markdown]
# course **505**value,there is no missng value
# there are **4** unique value in gender column
# 2024-04-20 indicates most frequent value in that column
# frequent value **143** number of time the value have been repeated

# %% [markdown]
# ## batch_type

# %% [markdown]
# batch_type**2**value,there is no missng value
# there are **4** unique value in gender column
# weekend  indicates most frequent value in that column
# frequent value **263** number of time the value have been repeated

# %% [markdown]
# ## total_sessions

# %% [markdown]
# total_sessions have **505**value,there is no missng value
# total_sessions mean grater than std,thats mean data is less variated
# 25% of data **120** data lies below this value
# 50% of data **120** data lies below this value
# 75% of data **120** data lies below this vallue
# total_sessions min value is 120,and max value is 120

# %% [markdown]
# ## sessions_attended

# %% [markdown]
# sessions_attended have **505**value,there is no missng value
# sessions_attened mean grater than std,thats mean data is strong and stable
# 25% of data **73** data lies below this value
# 50% of data **88** data lies below this value
# 75% of data **103** data lies below this vallue
# total_sessions min value is 60,and max value is 119

# %% [markdown]
# ## avg_quiz_score

# %% [markdown]
# avg_quiz_score have **505**value,there is no missng value
# avg_quiz_score mean grater than std,thats mean data is strong and stable
# 25% of data **56** data lies below this value
# 50% of data **69** data lies below this value
# 75% of data **84** data lies below this vallue
# total_sessions min value is 40 ,and max value is 99

# %% [markdown]
# ## assignment_score

# %% [markdown]
# assignment_score have **505**value,there is no missng value
# assignment_score mean grater than std,thats mean data is strong and stable
# 25% of data **56** data lies below this value
# 50% of data **69** data lies below this value
# 75% of data **84** data lies below this vallue
# total_sessions min value is 40 ,and max value is 99

# %% [markdown]
# ## project_score

# %% [markdown]
# project_score have **505**value,there is no missng value
# project_score mean grater than std,thats mean data is strong and stable
# 25% of data **62** data lies below this value
# 50% of data **76** data lies below this value
# 75% of data **88** data lies below this vallue
# total_sessions min value is 50 ,and max value is 99

# %% [markdown]
# ## final_rating

# %% [markdown]
# final_rating have **505**value,there is no missng value
# final_rating mean grater than std,thats mean data is strong and stable
# 25% of data **2** data lies below this value
# 50% of data **3** data lies below this value
# 75% of data **4** data lies below this vallue
# total_sessions min value is 2,and max value is 5

# %% [markdown]
# ## learning_hours

# %% [markdown]
# learning_hours have **505**value,there is no missng value is present in column
# learning_hours mean grater than std,thats mean data is strong and stable
# 25% of data **2** data lies below this value
# 50% of data **3** data lies below this value
# 75% of data **4** data lies below this vallue
# total_sessions min value is 2,and max value is 5

# %% [markdown]
# ## placement_status

# %% [markdown]
# city have **505**value,there is no missng value
# there are **2** unique value in city column
# placed indicates most frequent value in that column
# frequent value **336** number of time the value have been repeated

# %% [markdown]
# ## feedback_score

# %% [markdown]
# feedback_score have **505**value,there is no missng value
# feedback_score mean grater than std,thats mean data is strong and stable
# 25% of data **6** data lies below this value
# 50% of data **7** data lies below this value
# 75% of data **8** data lies below this vallue
# total_sessions min value is 5 ,and max value is 9

# %% [markdown]
# ## attendance_pct

# %% [markdown]
# attendance_pct have **505**value,there is no missng value
# attendance_pct mean grater than std,thats mean data is strong and stable
# 25% of data **60** data lies below this value
# 50% of data **73** data lies below this value
# 75% of data **85** data lies below this vallue
# total_sessions min value is 50,and max value is 99

# %% [markdown]
# ## salary_offered

# %% [markdown]
# salart_offered have **505**value,there is no missng value
# salary_offered mean grater than std,thats mean data is strong and stable
# 25% of data **5** data lies below this valuew
# 50% of data **7** data lies below this value
# 75% of data **1** data lies below this vallue
# total_sessions min value is 3,and max value is 1

# %%
#7. Identify columns that contain missing values.
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender               505
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
#8. Count the number of missing values in each column.
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender               505
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
#9. Calculate the percentage of missing values in the final_rating column.

# %%
#10. Fill missing values in the final_rating column using the mean.

# %%
#11. Verify that missing values in final_rating are handled.
df['final_rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
#12. Check whether duplicate records exist in the dataset.
# df.isna().sum()
df[df.duplicated()]
# Out:
#      student_id student_name gender       city enrollment_date         course  \
# 500        1452  Student_452    NaN     Mumbai      2024-03-07  Generative AI
# 501        1276  Student_276    NaN  Hyderabad      2024-10-15  Generative AI
# 502        1210  Student_210    NaN  Bangalore      2024-04-04        AI & ML
# 503        1178  Student_178    NaN      Delhi      2024-01-20  Generative AI
# 504        1397  Student_397    NaN     Mumbai      2024-05-27  Generative AI
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 500    Weekday             120                 68              84
# 501    Weekday             120                 95              92
# 502    Weekday             120                 75              40
# 503    Weekday             120                 80              97
# 504    Weekend             120                101              66
#
#      assignment_score  project_score  final_rating  learning_hours  \
# ...

# %%
#13. Count the total number of duplicate rows.
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
#14. Display all duplicate records.
df[df.duplicated()]
# Out:
#      student_id student_name gender       city enrollment_date         course  \
# 500        1452  Student_452    NaN     Mumbai      2024-03-07  Generative AI
# 501        1276  Student_276    NaN  Hyderabad      2024-10-15  Generative AI
# 502        1210  Student_210    NaN  Bangalore      2024-04-04        AI & ML
# 503        1178  Student_178    NaN      Delhi      2024-01-20  Generative AI
# 504        1397  Student_397    NaN     Mumbai      2024-05-27  Generative AI
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 500    Weekday             120                 68              84
# 501    Weekday             120                 95              92
# 502    Weekday             120                 75              40
# 503    Weekday             120                 80              97
# 504    Weekend             120                101              66
#
#      assignment_score  project_score  final_rating  learning_hours  \
# ...

# %%
#15. Remove duplicate records from the dataset.

# %%
df["salary_offered"].fillna(df["salary_offered"].mean(),inplace=True)
# Out:
# C:\Users\PRASHANT\AppData\Local\Temp\ipykernel_33996\2245153338.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["salary_offered"].fillna(df["salary_offered"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender               505
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating           0
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered         0
# dtype: int64

# %%
#16. Verify the dataset size after removing duplicates.
print(df.size)
# Out:
# 9090
# (505, 18)

# %%
#17. Find the number of unique values in the city column.
df["city"].nunique()
# Out:
# 6

# %%
#18. Find the number of unique values in the course column.
df["course"].nunique()
# Out:
# 4

# %%
#19. Display all unique cities present in the dataset.
df["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Delhi', 'Mumbai', 'Chennai', 'Bangalore'],
#       dtype=object)

# %%
#20. Count the number of students in each city.
df["city"].value_counts()
# Out:
# city
# Hyderabad    100
# Mumbai        95
# Pune          87
# Bangalore     82
# Chennai       73
# Delhi         68
# Name: count, dtype: int64

# %%
#21. Count the number of students enrolled in each course.
df["course"].value_counts()
# Out:
# course
# Data Analytics    143
# Data Science      128
# AI & ML           126
# Generative AI     108
# Name: count, dtype: int64

# %%
#22. Identify the course with the highest student enrollment.
df["course"].max()
# Out:
# 'Generative AI'

# %%
#23. Count the number of students who are placed and not placed.
df["placement_status"].value_counts()s]
# Out:
# placement_status
# Placed        336
# Not Placed    169
# Name: count, dtype: int64

# %%
#24. Filter students whose attendance percentage is greater than 80.
df[df.attendance_pct>=80]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# ..          ...          ...     ...        ...             ...
# 475        1476  Student_476  Female    Chennai      2024-02-05
# 477        1478  Student_478  Female     Mumbai      2024-07-06
# 481        1482  Student_482  Female     Mumbai      2024-07-15
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# ...

# %%
#25. Filter students who attended fewer than 70 sessions.
df[df.sessions_attended>=70]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %%
#26. Filter students with an average quiz score above 85.
df[df.avg_quiz_score>=85]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 12         1013   Student_13    Male    Chennai      2024-04-20
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 15         1016   Student_16    Male     Mumbai      2024-07-01
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# ..          ...          ...     ...        ...             ...
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 503        1178  Student_178    Male      Delhi      2024-01-20
#
#              course batch_type  total_sessions  sessions_attended  \
# 6    Data Analytics    Weekend             120                112
# ...

# %%
#27. Filter students enrolled in the Data Science course.
df[df["course"].isin(["Data Science"])]
# Out:
#      student_id student_name  gender       city enrollment_date        course  \
# 2          1003    Student_3    Male       Pune      2024-12-05  Data Science
# 7          1008    Student_8    Male    Chennai      2024-07-23  Data Science
# 10         1011   Student_11    Male    Chennai      2024-02-12  Data Science
# 13         1014   Student_14    Male     Mumbai      2024-09-05  Data Science
# 18         1019   Student_19  Female       Pune      2024-01-08  Data Science
# ..          ...          ...     ...        ...             ...           ...
# 487        1488  Student_488  Female       Pune      2024-09-17  Data Science
# 489        1490  Student_490    Male       Pune      2024-09-12  Data Science
# 490        1491  Student_491  Female  Bangalore      2024-08-09  Data Science
# 495        1496  Student_496    Male  Hyderabad      2024-12-29  Data Science
# 498        1499  Student_499    Male     Mumbai      2024-07-20  Data Science
#
# ...

# %%
#28. Filter students who are not placed and attended more than 75 sessions.
df[(df["placement_status"]=="not placed") & (df.sessions_attended>=75)]
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, gender, city, enrollment_date, course, batch_type, total_sessions, sessions_attended, avg_quiz_score, assignment_score, project_score, final_rating, learning_hours, placement_status, feedback_score, attendance_pct, salary_offered]
# Index: []

# %%
#29. Filter students belonging to Pune, Bangalore, or Hyderabad.
df[df["city"].isin(["Pune","Bangalore","Hyderbad"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 2          1003    Student_3    Male       Pune      2024-12-05
# 5          1006    Student_6  Female       Pune      2024-09-18
# 18         1019   Student_19  Female       Pune      2024-01-08
# 19         1020   Student_20    Male       Pune      2024-12-25
# 20         1021   Student_21  Female       Pune      2024-07-02
# ..          ...          ...     ...        ...             ...
# 490        1491  Student_491  Female  Bangalore      2024-08-09
# 494        1495  Student_495    Male       Pune      2024-12-07
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 499        1500  Student_500  Female       Pune      2024-06-06
# 502        1210  Student_210    Male  Bangalore      2024-04-04
#
#              course batch_type  total_sessions  sessions_attended  \
# 2      Data Science    Weekday             120                 73
# ...

# %%
#30. Filter students enrolled in AI & ML or Generative AI courses.
df[df["course"].isin(["AI & ML","Generative AI"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 5          1006    Student_6  Female       Pune      2024-09-18
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %%
#31. Filter students whose average quiz score lies between 60 and 80.
df[df["avg_quiz_score"].between(60,80)]
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 3          1004    Student_4    Male    Delhi      2024-03-09         AI & ML
# 5          1006    Student_6  Female     Pune      2024-09-18   Generative AI
# 7          1008    Student_8    Male  Chennai      2024-07-23    Data Science
# 8          1009    Student_9    Male   Mumbai      2024-05-05         AI & ML
# 9          1010   Student_10  Female    Delhi      2024-08-22  Data Analytics
# ..          ...          ...     ...      ...             ...             ...
# 489        1490  Student_490    Male     Pune      2024-09-12    Data Science
# 493        1494  Student_494  Female    Delhi      2024-12-20   Generative AI
# 494        1495  Student_495    Male     Pune      2024-12-07         AI & ML
# 498        1499  Student_499    Male   Mumbai      2024-07-20    Data Science
# 504        1397  Student_397  Female   Mumbai      2024-05-27   Generative AI
#
# ...

# %%
#32. Filter students whose assignment score lies between 70 and 90.
df[df["assignment_score"].between(70,90)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 2          1003    Student_3    Male       Pune      2024-12-05
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 20         1021   Student_21  Female       Pune      2024-07-02
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 2      Data Science    Weekday             120                 73
# ...

# %%
#33. Filter students whose learning hours lie between 10 and 25.
df[df["learning_hours"].between(10,25)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 8          1009    Student_9    Male     Mumbai      2024-05-05
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 4    Generative AI    Weekday             120                101
# ...

# %%
#34. Create a new column total_score as the sum of quiz, assignment, and project scores.

# %%
#35. Create a new column attendance_flag based on attendance percentage.
def percentage(x):
    if x>75:
        return "Good"
    else:
        return "Not Good"
df["attendance_flag"]=df["attendance_pct"].apply(percentage)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating learning_hours  \
# ...

# %%
#36. Create a new column learning_intensity based on learning hours.
def learning_intensity(x):
    if x>=75:
        return "high"
    else:
        return "low"
df["learning_hours"]=df["learning_hours"].apply(learning_intensity)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating learning_hours  \
# ...

# %%
#37. Classify students based on total_score using apply().

# %%
#38. Create a placement eligibility column using apply().

# %%
#39. Map placement_status values to numerical values.
df['placement_status'] = df['placement_status'].map({'Placed':1, 'Not Placed':0})

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating learning_hours  \
# ...

# %%
#40. Map batch_type values to abbreviated codes.
df['batch_type_code']= df['batch_type'].map(batch_type_map)

# %%
# 41.Map gender values to single-letter codes.
gender_val={
    "Female":"F",
    "Male":"M"}
df["gender"]=df["student_name"].map(gender_val)

# %%
df.head()
# Out:
#    student_id student_name gender       city enrollment_date         course  \
# 0        1001    Student_1    NaN  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2    NaN  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    NaN       Pune      2024-12-05   Data Science
# 3        1004    Student_4    NaN      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    NaN     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating  learning_hours  \
# ...

# %%
#42.Count students under each learning_intensity category

# %%
#43.Calculate the percentage of placement-eligible students.
df["placement_status"].value_counts()%100
# Out:
# placement_status
# 1    36
# 0    69
# Name: count, dtype: int64

# %%
#44.Identify the city with the highest number of placed stude
df["city"].max()
# Out:
# 'Pune'

# %%
#45.Compare average total_score for placed and not placed students.

# %%
#46.Identify the top 5 students based on total_score.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23232\3661429449.py in ?()
#       1 #46.Identify the top 5 students based on total_score.
# ----> 2 df.sort_values(by='total_score', ascending=False)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
# ...
